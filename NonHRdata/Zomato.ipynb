# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.1'

# %%
data = pd.read_csv("zomato.csv")

# %%
data.head(2)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address            name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...           Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                    080 41714161
#
#        location      rest_type  \
# 0  Banashankari  Casual Dining
# 1  Banashankari  Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines approx_cost(for two people)  \
# ...

# %%
data.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='str')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  str
#  1   address                      51717 non-null  str
#  2   name                         51717 non-null  str
#  3   online_order                 51717 non-null  str
#  4   book_table                   51717 non-null  str
#  5   rate                         43942 non-null  str
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  str
#  8   location                     51696 non-null  str
#  9   rest_type                    51490 non-null  str
#  10  dish_liked                   23639 non-null  str
#  11  cuisines                     51672 non-null  str
#  12  approx_cost(for two people)  51371 non-null  str
# ...

# %%
data.shape
# Out:
# (51717, 17)

# %%
columms_to_keep = ['name', 'online_order', 'book_table', 'rate','dish_liked','approx_cost(for two people)']
columns_to_drop = ['url', 'address','phone', 'location', 'rest_type','votes','cuisines','reviews_list', 'menu_item','listed_in(type)', 'listed_in(city)']

# %%
data.shape
# Out:
# (51717, 17)

# %%
len(columms_to_keep)
# Out:
# 6

# %%
len(columns_to_drop)
# Out:
# 11

# %%
# 1st way - filtering data

# %%
columms_to_keep
# Out:
# ['name',
#  'online_order',
#  'book_table',
#  'rate',
#  'dish_liked',
#  'approx_cost(for two people)']

# %%
modify_data = data[columms_to_keep]

# %%
modify_data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %%
# 2nd way, dropping columns

# %%
columms_to_keep
# Out:
# ['name',
#  'online_order',
#  'book_table',
#  'rate',
#  'dish_liked',
#  'approx_cost(for two people)']

# %%
data.drop(columns= columns_to_drop, inplace= True)

# %%
data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %%
# Renaming columns

# %%
# Removing 1 by 1

# %%
data.rename(columns ={"name":"name1"})
# Out:
#                                                    name1 online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %%
data
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                                         dish_liked  \
# ...

# %%
data.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'dish_liked',
#        'approx_cost(for two people)'],
#       dtype='str')

# %%
data.columns[0].capitalize()
# Out:
# 'Name'

# %%
for i in data.columns:
    print(i.capitalize())
# Out:
# Name
# Online_order
# Book_table
# Rate
# Dish_liked
# Approx_cost(for two people)

# %%
new_column_names = []
for i in data.columns:
    new_column_names.append(i.capitalize())

# %%
new_column_names
# Out:
# ['Name',
#  'Online_order',
#  'Book_table',
#  'Rate',
#  'Dish_liked',
#  'Approx_cost(for two people)']

# %%
data.columns = new_column_names

# %%
data
# Out:
#                                                     Name Online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       Book_table    Rate                                         Dish_liked  \
# ...

# %%
# 3. Dropping duplicates

# %%
data.duplicated().value_counts()
# Out:
# True     32808
# False    18909
# Name: count, dtype: int64

# %%
data.drop_duplicates(inplace = True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# 4. Removing Nan values

# %%
data.isna().sum()
# Out:
# Name                               0
# Online_order                       0
# Book_table                         0
# Rate                            2418
# Dish_liked                     10587
# Approx_cost(for two people)      140
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                                               Name Online_order Book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# ...                                            ...          ...        ...
# 51611                                    Chung Wah           No         No
# 51617                              Breakfast House           No         No
# 51620                               Fujian Express          Yes         No
# 51628  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 51677                                      Bhagini           No         No
#
#          Rate                                         Dish_liked  \
# ...

# %%
data.reset_index(inplace= True)

# %%
data.drop(columns= "index", inplace=True)

# %%
data
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#         Rate                                         Dish_liked  \
# ...

# %%
# 4. Cleaning individual columns

# %%
data["Rate"][14]
# Out:
# '3.9/5'

# %%
data["Rate"]
# Out:
# 0        4.1/5
# 1        4.1/5
# 2        3.8/5
# 3        3.7/5
# 4        3.8/5
#          ...
# 8245    2.5 /5
# 8246    3.6 /5
# 8247    3.8 /5
# 8248    4.2 /5
# 8249    2.5 /5
# Name: Rate, Length: 8250, dtype: str

# %%
data["Rate"] = data["Rate"].str.replace(" ", "")

# %%
data
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#        Rate                                         Dish_liked  \
# ...

# %%
data["Rate"] = data["Rate"].str.replace("/"," out of ")

# %%
data
# Out:
#                                              Name Online_order Book_table  \
# 0                                           Jalsa          Yes        Yes
# 1                                  Spice Elephant          Yes         No
# 2                                 San Churro Cafe          Yes         No
# 3                           Addhuri Udupi Bhojana           No         No
# 4                                   Grand Village           No         No
# ...                                           ...          ...        ...
# 8245                                    Chung Wah           No         No
# 8246                              Breakfast House           No         No
# 8247                               Fujian Express          Yes         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park           No        Yes
# 8249                                      Bhagini           No         No
#
#               Rate                                         Dish_liked  \
# ...

# %%
# 5. check for more transformations. Turn text columns into numerical columns.

# %%
data["Online_order"]
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3        No
# 4        No
#        ...
# 8245     No
# 8246     No
# 8247    Yes
# 8248     No
# 8249     No
# Name: Online_order, Length: 8250, dtype: str

# %%
data["Online_order"] = data["Online_order"].apply(lambda x: 1 if x == "Yes" else 0)

# %%
data
# Out:
#                                              Name  Online_order Book_table  \
# 0                                           Jalsa             1        Yes
# 1                                  Spice Elephant             1         No
# 2                                 San Churro Cafe             1         No
# 3                           Addhuri Udupi Bhojana             0         No
# 4                                   Grand Village             0         No
# ...                                           ...           ...        ...
# 8245                                    Chung Wah             0         No
# 8246                              Breakfast House             0         No
# 8247                               Fujian Express             1         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park             0        Yes
# 8249                                      Bhagini             0         No
#
# ...

# %%
data.to_csv("Cleaned_csv_Zomato.csv")

# %%
pd.read_csv("Cleaned_csv_Zomato.csv")
# Out:
#       Unnamed: 0                                         Name  Online_order  \
# 0              0                                        Jalsa             1
# 1              1                               Spice Elephant             1
# 2              2                              San Churro Cafe             1
# 3              3                        Addhuri Udupi Bhojana             0
# 4              4                                Grand Village             0
# ...          ...                                          ...           ...
# 8245        8245                                    Chung Wah             0
# 8246        8246                              Breakfast House             0
# 8247        8247                               Fujian Express             1
# 8248        8248  Nook - Aloft Bengaluru Cessna Business Park             0
# 8249        8249                                      Bhagini             0
#
#      Book_table          Rate  \
# ...

# %%
data.to_csv("Cleaned_csv_Zomato_no_index.csv", index = False)

# %%
pd.read_csv("Cleaned_csv_Zomato_no_index.csv")
# Out:
#                                              Name  Online_order Book_table  \
# 0                                           Jalsa             1        Yes
# 1                                  Spice Elephant             1         No
# 2                                 San Churro Cafe             1         No
# 3                           Addhuri Udupi Bhojana             0         No
# 4                                   Grand Village             0         No
# ...                                           ...           ...        ...
# 8245                                    Chung Wah             0         No
# 8246                              Breakfast House             0         No
# 8247                               Fujian Express             1         No
# 8248  Nook - Aloft Bengaluru Cessna Business Park             0        Yes
# 8249                                      Bhagini             0         No
#
# ...
