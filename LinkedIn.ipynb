# %%
# 1. Loading data into pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("linkdin_Job_data.csv")

# %%
# 2. Check first and last 5 rows.

# %%
data.head(5)
# Out:
#        job_ID                                                job  \
# 0  3471657636  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1  3471669068  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2  3474349934                                 Data Analyst - WFH
# 3  3472816027                                       Data Analyst
# 4  3473311511                                       Data Analyst
#
#                          location  company_id              company_name  \
# 0             Delhi, Delhi, India         NaN                 Crossover
# 1         New Delhi, Delhi, India         NaN                 Crossover
# 2          Greater Bengaluru Area         NaN                    Uplers
# 3        Gurugram, Haryana, India         NaN             PVAR SERVICES
# 4  Mohali district, Punjab, India         NaN  Timeline Freight Brokers
#
#   work_type              full_time_remote  \
# 0    Remote         Full-time · Associate
# 1    Remote         Full-time · Associate
# 2    Remote  Full-time · Mid-Senior level
# 3   On-site                     Full-time
# 4   On-site                     Full-time
#
#                                         no_of_employ no_of_application  \
# 0  1,001-5,000 employees · IT Services and IT Con...               200
# 1  1,001-5,000 employees · IT Services and IT Con...               184
# 2  1,001-5,000 employees · IT Services and IT Con...               200
# 3                                     1-10 employees               200
# 4                                     1-10 employees                 8
#
#   posted_day_ago             alumni           Hiring_person  \
# 0        8 hours  12 company alumni                     NaN
# 1        8 hours  12 company alumni                     NaN
# 2        9 hours   3 company alumni            Shahid Ahmad
# 3        7 hours                NaN           Vartika Singh
# 4     26 minutes   1 company alumni  Manisha (Gisele Smith)
#
#     linkedin_followers                                 hiring_person_link  \
# 0  5,395,547 followers                                                NaN
# 1  5,395,547 followers                                                NaN
# 2                  NaN  https://www.linkedin.com/in/shahid-ahmad-a2613...
# 3      2,094 followers         https://www.linkedin.com/in/vartika-singh-
# 4                  NaN     https://www.linkedin.com/in/manisharathore0029
#
#                                          job_details
# 0  About the job Crossover is the world's #1 sour...
# 1  About the job Crossover is the world's #1 sour...
# 2  About the job Profile: ML EngineersExperience:...
# 3  About the job Designation: Data AnalystLocatio...
# 4  About the job The ideal candidate will use the...

# %%
data.tail(5)
# Out:
#           job_ID                             job                     location  \
# 7922  3472039871              Back End Developer         Kochi, Kerala, India
# 7923  3473194471      Software Engineer - Senior     Gurugram, Haryana, India
# 7924  3461005032                          Vue JS  Hyderabad, Telangana, India
# 7925  3474305684                   iOS Developer  Bengaluru, Karnataka, India
# 7926  3459352801  Power train function developer  Bengaluru, Karnataka, India
#
#       company_id               company_name work_type  \
# 7922         NaN           Orion Innovation    Hybrid
# 7923         NaN                     Uplers   On-site
# 7924         NaN  Tata Consultancy Services   On-site
# 7925         NaN                     Uplers    Remote
# 7926         NaN                    Akkodis    Hybrid
#
#                   full_time_remote  \
# 7922         Full-time · Associate
# 7923  Full-time · Mid-Senior level
# 7924  Full-time · Mid-Senior level
# 7925  Full-time · Mid-Senior level
# 7926  Full-time · Mid-Senior level
#
#                                            no_of_employ no_of_application  \
# 7922  5,001-10,000 employees · IT Services and IT Co...                25
# 7923  1,001-5,000 employees · IT Services and IT Con...                18
# 7924  10,001+ employees · IT Services and IT Consulting                15
# 7925  1,001-5,000 employees · IT Services and IT Con...                17
# 7926  10,001+ employees · IT Services and IT Consulting                43
#
#      posted_day_ago                 alumni         Hiring_person  \
# 7922         2 days      24 company alumni  Poornima Viswanathan
# 7923         2 days       3 company alumni         Tejveer Singh
# 7924         6 days  10,080 company alumni          ANNIE ANTONY
# 7925          1 day       3 company alumni           Arjun Jaggi
# 7926         1 week      27 company alumni                   NaN
#
#         linkedin_followers                                 hiring_person_link  \
# 7922                   NaN  https://www.linkedin.com/in/poornima-viswanath...
# 7923                   NaN  https://www.linkedin.com/in/tejveer-singh-a348...
# 7924  11,923,634 followers  https://www.linkedin.com/in/annie-antony-a1041...
# 7925                   NaN            https://www.linkedin.com/in/arjunjaggi7
# 7926   1,421,090 followers                                                NaN
#
#                                             job_details
# 7922  About the job The ideal candidate will show in...
# 7923  About the job Experience: 4 - 8 yearsProfile: ...
# 7924  About the job Role- Vue js DeveloperExperience...
# 7925  About the job Profile: iOS DeveloperExperience...
# 7926  About the job JD Powertrain Function Developer...

# %%
# 4. Information of data

# %%
data.info
# Out:
# <bound method DataFrame.info of           job_ID                                                job  \
# 0     3471657636  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1     3471669068  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2     3474349934                                 Data Analyst - WFH
# 3     3472816027                                       Data Analyst
# 4     3473311511                                       Data Analyst
# ...          ...                                                ...
# 7922  3472039871                                 Back End Developer
# 7923  3473194471                         Software Engineer - Senior
# 7924  3461005032                                             Vue JS
# 7925  3474305684                                      iOS Developer
# 7926  3459352801                     Power train function developer
#
#                             location  company_id               company_name  \
# 0                Delhi, Delhi, India         NaN                  Crossover
# 1            New Delhi, Delhi, India         NaN                  Crossover
# 2             Greater Bengaluru Area         NaN                     Uplers
# 3           Gurugram, Haryana, India         NaN              PVAR SERVICES
# 4     Mohali district, Punjab, India         NaN   Timeline Freight Brokers
# ...                              ...         ...                        ...
# 7922            Kochi, Kerala, India         NaN           Orion Innovation
# 7923        Gurugram, Haryana, India         NaN                     Uplers
# 7924     Hyderabad, Telangana, India         NaN  Tata Consultancy Services
# 7925     Bengaluru, Karnataka, India         NaN                     Uplers
# 7926     Bengaluru, Karnataka, India         NaN                    Akkodis
#
#      work_type              full_time_remote  \
# 0       Remote         Full-time · Associate
# 1       Remote         Full-time · Associate
# 2       Remote  Full-time · Mid-Senior level
# 3      On-site                     Full-time
# 4      On-site                     Full-time
# ...        ...                           ...
# 7922    Hybrid         Full-time · Associate
# 7923   On-site  Full-time · Mid-Senior level
# 7924   On-site  Full-time · Mid-Senior level
# 7925    Remote  Full-time · Mid-Senior level
# 7926    Hybrid  Full-time · Mid-Senior level
#
#                                            no_of_employ no_of_application  \
# 0     1,001-5,000 employees · IT Services and IT Con...               200
# 1     1,001-5,000 employees · IT Services and IT Con...               184
# 2     1,001-5,000 employees · IT Services and IT Con...               200
# 3                                        1-10 employees               200
# 4                                        1-10 employees                 8
# ...                                                 ...               ...
# 7922  5,001-10,000 employees · IT Services and IT Co...                25
# 7923  1,001-5,000 employees · IT Services and IT Con...                18
# 7924  10,001+ employees · IT Services and IT Consulting                15
# 7925  1,001-5,000 employees · IT Services and IT Con...                17
# 7926  10,001+ employees · IT Services and IT Consulting                43
#
#      posted_day_ago                 alumni           Hiring_person  \
# 0           8 hours      12 company alumni                     NaN
# 1           8 hours      12 company alumni                     NaN
# 2           9 hours       3 company alumni            Shahid Ahmad
# 3           7 hours                    NaN           Vartika Singh
# 4        26 minutes       1 company alumni  Manisha (Gisele Smith)
# ...             ...                    ...                     ...
# 7922         2 days      24 company alumni    Poornima Viswanathan
# 7923         2 days       3 company alumni           Tejveer Singh
# 7924         6 days  10,080 company alumni            ANNIE ANTONY
# 7925          1 day       3 company alumni             Arjun Jaggi
# 7926         1 week      27 company alumni                     NaN
#
#         linkedin_followers                                 hiring_person_link  \
# 0      5,395,547 followers                                                NaN
# 1      5,395,547 followers                                                NaN
# 2                      NaN  https://www.linkedin.com/in/shahid-ahmad-a2613...
# 3          2,094 followers         https://www.linkedin.com/in/vartika-singh-
# 4                      NaN     https://www.linkedin.com/in/manisharathore0029
# ...                    ...                                                ...
# 7922                   NaN  https://www.linkedin.com/in/poornima-viswanath...
# 7923                   NaN  https://www.linkedin.com/in/tejveer-singh-a348...
# 7924  11,923,634 followers  https://www.linkedin.com/in/annie-antony-a1041...
# 7925                   NaN            https://www.linkedin.com/in/arjunjaggi7
# 7926   1,421,090 followers                                                NaN
#
#                                             job_details
# 0     About the job Crossover is the world's #1 sour...
# 1     About the job Crossover is the world's #1 sour...
# 2     About the job Profile: ML EngineersExperience:...
# 3     About the job Designation: Data AnalystLocatio...
# 4     About the job The ideal candidate will use the...
# ...                                                 ...
# 7922  About the job The ideal candidate will show in...
# 7923  About the job Experience: 4 - 8 yearsProfile: ...
# 7924  About the job Role- Vue js DeveloperExperience...
# 7925  About the job Profile: iOS DeveloperExperience...
# 7926  About the job JD Powertrain Function Developer...
#
# [7927 rows x 15 columns]>

# %%
# 5. Checking Nan values

# %%
data.isna().sum()
# Out:
# job_ID                   0
# job                     33
# location                33
# company_id            7927
# company_name            35
# work_type              191
# full_time_remote        79
# no_of_employ           324
# no_of_application       40
# posted_day_ago           7
# alumni                3069
# Hiring_person         2207
# linkedin_followers    3113
# hiring_person_link    2207
# job_details             46
# dtype: int64

# %%
# 6. Total rows and columns

# %%
data.shape
# Out:
# (7927, 15)

# %%
# 7. Removing duplicates

# %%
data.duplicated().value_counts()
# Out:
# False    7848
# True       79
# Name: count, dtype: int64

# %%
data.drop_duplicates(inplace = True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.shape
# Out:
# (7848, 15)

# %%
data
# Out:
#           job_ID                                                job  \
# 0     3471657636  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1     3471669068  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2     3474349934                                 Data Analyst - WFH
# 3     3472816027                                       Data Analyst
# 4     3473311511                                       Data Analyst
# ...          ...                                                ...
# 7922  3472039871                                 Back End Developer
# 7923  3473194471                         Software Engineer - Senior
# 7924  3461005032                                             Vue JS
# 7925  3474305684                                      iOS Developer
# 7926  3459352801                     Power train function developer
#
#                             location  company_id               company_name  \
# 0                Delhi, Delhi, India         NaN                  Crossover
# 1            New Delhi, Delhi, India         NaN                  Crossover
# 2             Greater Bengaluru Area         NaN                     Uplers
# 3           Gurugram, Haryana, India         NaN              PVAR SERVICES
# 4     Mohali district, Punjab, India         NaN   Timeline Freight Brokers
# ...                              ...         ...                        ...
# 7922            Kochi, Kerala, India         NaN           Orion Innovation
# 7923        Gurugram, Haryana, India         NaN                     Uplers
# 7924     Hyderabad, Telangana, India         NaN  Tata Consultancy Services
# 7925     Bengaluru, Karnataka, India         NaN                     Uplers
# 7926     Bengaluru, Karnataka, India         NaN                    Akkodis
#
#      work_type              full_time_remote  \
# 0       Remote         Full-time · Associate
# 1       Remote         Full-time · Associate
# 2       Remote  Full-time · Mid-Senior level
# 3      On-site                     Full-time
# 4      On-site                     Full-time
# ...        ...                           ...
# 7922    Hybrid         Full-time · Associate
# 7923   On-site  Full-time · Mid-Senior level
# 7924   On-site  Full-time · Mid-Senior level
# 7925    Remote  Full-time · Mid-Senior level
# 7926    Hybrid  Full-time · Mid-Senior level
#
#                                            no_of_employ no_of_application  \
# 0     1,001-5,000 employees · IT Services and IT Con...               200
# 1     1,001-5,000 employees · IT Services and IT Con...               184
# 2     1,001-5,000 employees · IT Services and IT Con...               200
# 3                                        1-10 employees               200
# 4                                        1-10 employees                 8
# ...                                                 ...               ...
# 7922  5,001-10,000 employees · IT Services and IT Co...                25
# 7923  1,001-5,000 employees · IT Services and IT Con...                18
# 7924  10,001+ employees · IT Services and IT Consulting                15
# 7925  1,001-5,000 employees · IT Services and IT Con...                17
# 7926  10,001+ employees · IT Services and IT Consulting                43
#
#      posted_day_ago                 alumni           Hiring_person  \
# 0           8 hours      12 company alumni                     NaN
# 1           8 hours      12 company alumni                     NaN
# 2           9 hours       3 company alumni            Shahid Ahmad
# 3           7 hours                    NaN           Vartika Singh
# 4        26 minutes       1 company alumni  Manisha (Gisele Smith)
# ...             ...                    ...                     ...
# 7922         2 days      24 company alumni    Poornima Viswanathan
# 7923         2 days       3 company alumni           Tejveer Singh
# 7924         6 days  10,080 company alumni            ANNIE ANTONY
# 7925          1 day       3 company alumni             Arjun Jaggi
# 7926         1 week      27 company alumni                     NaN
#
#         linkedin_followers                                 hiring_person_link  \
# 0      5,395,547 followers                                                NaN
# 1      5,395,547 followers                                                NaN
# 2                      NaN  https://www.linkedin.com/in/shahid-ahmad-a2613...
# 3          2,094 followers         https://www.linkedin.com/in/vartika-singh-
# 4                      NaN     https://www.linkedin.com/in/manisharathore0029
# ...                    ...                                                ...
# 7922                   NaN  https://www.linkedin.com/in/poornima-viswanath...
# 7923                   NaN  https://www.linkedin.com/in/tejveer-singh-a348...
# 7924  11,923,634 followers  https://www.linkedin.com/in/annie-antony-a1041...
# 7925                   NaN            https://www.linkedin.com/in/arjunjaggi7
# 7926   1,421,090 followers                                                NaN
#
#                                             job_details
# 0     About the job Crossover is the world's #1 sour...
# 1     About the job Crossover is the world's #1 sour...
# 2     About the job Profile: ML EngineersExperience:...
# 3     About the job Designation: Data AnalystLocatio...
# 4     About the job The ideal candidate will use the...
# ...                                                 ...
# 7922  About the job The ideal candidate will show in...
# 7923  About the job Experience: 4 - 8 yearsProfile: ...
# 7924  About the job Role- Vue js DeveloperExperience...
# 7925  About the job Profile: iOS DeveloperExperience...
# 7926  About the job JD Powertrain Function Developer...
#
# [7848 rows x 15 columns]

# %%
# 8. Assign a unique numerical identifier to each company in the 'company_ID' column and add it in a 'company_id' column based on the company's order of appearance in the DataFrame.

# %%
labels, _ = pd.factorize(data['company_name'])
data['company_id'] = labels + 1

# %%
data.head(3)
# Out:
#        job_ID                                                job  \
# 0  3471657636  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1  3471669068  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2  3474349934                                 Data Analyst - WFH
#
#                   location  company_id company_name work_type  \
# 0      Delhi, Delhi, India           1    Crossover    Remote
# 1  New Delhi, Delhi, India           1    Crossover    Remote
# 2   Greater Bengaluru Area           2       Uplers    Remote
#
#                full_time_remote  \
# 0         Full-time · Associate
# 1         Full-time · Associate
# 2  Full-time · Mid-Senior level
#
#                                         no_of_employ no_of_application  \
# 0  1,001-5,000 employees · IT Services and IT Con...               200
# 1  1,001-5,000 employees · IT Services and IT Con...               184
# 2  1,001-5,000 employees · IT Services and IT Con...               200
#
#   posted_day_ago             alumni Hiring_person   linkedin_followers  \
# 0        8 hours  12 company alumni           NaN  5,395,547 followers
# 1        8 hours  12 company alumni           NaN  5,395,547 followers
# 2        9 hours   3 company alumni  Shahid Ahmad                  NaN
#
#                                   hiring_person_link  \
# 0                                                NaN
# 1                                                NaN
# 2  https://www.linkedin.com/in/shahid-ahmad-a2613...
#
#                                          job_details
# 0  About the job Crossover is the world's #1 sour...
# 1  About the job Crossover is the world's #1 sour...
# 2  About the job Profile: ML EngineersExperience:...

# %%
# 9. Drop unneccessary columns

# %%
data.columns
# Out:
# Index(['job_ID', 'job', 'location', 'company_id', 'company_name', 'work_type',
#        'full_time_remote', 'no_of_employ', 'no_of_application',
#        'posted_day_ago', 'alumni', 'Hiring_person', 'linkedin_followers',
#        'hiring_person_link', 'job_details'],
#       dtype='str')

# %%
columns_to_drop = ['alumni', 'hiring_person_link']
columns_to_keep = ['job_ID', 'job', 'location', 'company_id', 'company_name', 'work_type',
       'full_time_remote', 'no_of_employ', 'no_of_application',
       'posted_day_ago','Hiring_person', 'linkedin_followers', 'job_details']

# %%
columns_to_keep
# Out:
# ['job_ID',
#  'job',
#  'location',
#  'company_id',
#  'company_name',
#  'work_type',
#  'full_time_remote',
#  'no_of_employ',
#  'no_of_application',
#  'posted_day_ago',
#  'Hiring_person',
#  'linkedin_followers',
#  'job_details']

# %%
len(columns_to_keep)
# Out:
# 13

# %%
data = data[columns_to_keep]

# %%
data
# Out:
#           job_ID                                                job  \
# 0     3471657636  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1     3471669068  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2     3474349934                                 Data Analyst - WFH
# 3     3472816027                                       Data Analyst
# 4     3473311511                                       Data Analyst
# ...          ...                                                ...
# 7922  3472039871                                 Back End Developer
# 7923  3473194471                         Software Engineer - Senior
# 7924  3461005032                                             Vue JS
# 7925  3474305684                                      iOS Developer
# 7926  3459352801                     Power train function developer
#
#                             location  company_id               company_name  \
# 0                Delhi, Delhi, India           1                  Crossover
# 1            New Delhi, Delhi, India           1                  Crossover
# 2             Greater Bengaluru Area           2                     Uplers
# 3           Gurugram, Haryana, India           3              PVAR SERVICES
# 4     Mohali district, Punjab, India           4   Timeline Freight Brokers
# ...                              ...         ...                        ...
# 7922            Kochi, Kerala, India         105           Orion Innovation
# 7923        Gurugram, Haryana, India           2                     Uplers
# 7924     Hyderabad, Telangana, India          22  Tata Consultancy Services
# 7925     Bengaluru, Karnataka, India           2                     Uplers
# 7926     Bengaluru, Karnataka, India        2495                    Akkodis
#
#      work_type              full_time_remote  \
# 0       Remote         Full-time · Associate
# 1       Remote         Full-time · Associate
# 2       Remote  Full-time · Mid-Senior level
# 3      On-site                     Full-time
# 4      On-site                     Full-time
# ...        ...                           ...
# 7922    Hybrid         Full-time · Associate
# 7923   On-site  Full-time · Mid-Senior level
# 7924   On-site  Full-time · Mid-Senior level
# 7925    Remote  Full-time · Mid-Senior level
# 7926    Hybrid  Full-time · Mid-Senior level
#
#                                            no_of_employ no_of_application  \
# 0     1,001-5,000 employees · IT Services and IT Con...               200
# 1     1,001-5,000 employees · IT Services and IT Con...               184
# 2     1,001-5,000 employees · IT Services and IT Con...               200
# 3                                        1-10 employees               200
# 4                                        1-10 employees                 8
# ...                                                 ...               ...
# 7922  5,001-10,000 employees · IT Services and IT Co...                25
# 7923  1,001-5,000 employees · IT Services and IT Con...                18
# 7924  10,001+ employees · IT Services and IT Consulting                15
# 7925  1,001-5,000 employees · IT Services and IT Con...                17
# 7926  10,001+ employees · IT Services and IT Consulting                43
#
#      posted_day_ago           Hiring_person    linkedin_followers  \
# 0           8 hours                     NaN   5,395,547 followers
# 1           8 hours                     NaN   5,395,547 followers
# 2           9 hours            Shahid Ahmad                   NaN
# 3           7 hours           Vartika Singh       2,094 followers
# 4        26 minutes  Manisha (Gisele Smith)                   NaN
# ...             ...                     ...                   ...
# 7922         2 days    Poornima Viswanathan                   NaN
# 7923         2 days           Tejveer Singh                   NaN
# 7924         6 days            ANNIE ANTONY  11,923,634 followers
# 7925          1 day             Arjun Jaggi                   NaN
# 7926         1 week                     NaN   1,421,090 followers
#
#                                             job_details
# 0     About the job Crossover is the world's #1 sour...
# 1     About the job Crossover is the world's #1 sour...
# 2     About the job Profile: ML EngineersExperience:...
# 3     About the job Designation: Data AnalystLocatio...
# 4     About the job The ideal candidate will use the...
# ...                                                 ...
# 7922  About the job The ideal candidate will show in...
# 7923  About the job Experience: 4 - 8 yearsProfile: ...
# 7924  About the job Role- Vue js DeveloperExperience...
# 7925  About the job Profile: iOS DeveloperExperience...
# 7926  About the job JD Powertrain Function Developer...
#
# [7848 rows x 13 columns]

# %%
# 10. checking Nan values

# %%
data.isna().sum()
# Out:
# job_ID                   0
# job                     33
# location                33
# company_id               0
# company_name            35
# work_type              188
# full_time_remote        79
# no_of_employ           310
# no_of_application       40
# posted_day_ago           7
# Hiring_person         2188
# linkedin_followers    3078
# job_details             46
# dtype: int64

# %%
data.dropna(inplace= True)

# %%
data
# Out:
#           job_ID                             job                     location  \
# 3     3472816027                    Data Analyst     Gurugram, Haryana, India
# 7     3472808738               Shopify Developer                 Delhi, India
# 8     3475061559              Database Developer     Gurugram, Haryana, India
# 10    3471883751               Shopify Developer  Noida, Uttar Pradesh, India
# 11    3467390929                   Data Engineer     Gurugram, Haryana, India
# ...          ...                             ...                          ...
# 7917  3466122931   LINUX DEVICE DRIVER DEVELOPER  Bengaluru, Karnataka, India
# 7918  3469629784  Senior Java Software Developer     Pune, Maharashtra, India
# 7919  3471741258            AWS Cloud Specialist  Hyderabad, Telangana, India
# 7920  3466165399                   LTE Developer  Hyderabad, Telangana, India
# 7924  3461005032                          Vue JS  Hyderabad, Telangana, India
#
#       company_id                company_name work_type  \
# 3              3               PVAR SERVICES   On-site
# 7              6         Digital Impressions   On-site
# 8              7             Kline & Company    Hybrid
# 10             9       Unitalks Technologies    Remote
# 11            10                 ReNew Power   On-site
# ...          ...                         ...       ...
# 7917        2492  SmartSoC Solutions Pvt Ltd   On-site
# 7918        2493                     EPMware    Remote
# 7919        2494                       Altvu    Hybrid
# 7920          22   Tata Consultancy Services    Hybrid
# 7924          22   Tata Consultancy Services   On-site
#
#                   full_time_remote  \
# 3                        Full-time
# 7                        Full-time
# 8                        Full-time
# 10                       Full-time
# 11    Full-time · Mid-Senior level
# ...                            ...
# 7917   Contract · Mid-Senior level
# 7918                     Full-time
# 7919  Full-time · Mid-Senior level
# 7920                     Full-time
# 7924  Full-time · Mid-Senior level
#
#                                            no_of_employ no_of_application  \
# 3                                        1-10 employees               200
# 7                                      51-200 employees                 2
# 8                                     201-500 employees                 7
# 10                                      11-50 employees                22
# 11    501-1,000 employees · Renewable Energy Semicon...               111
# ...                                                 ...               ...
# 7917    201-500 employees · Semiconductor Manufacturing                10
# 7918                                    11-50 employees                99
# 7919       201-500 employees · Human Resources Services                52
# 7920  10,001+ employees · IT Services and IT Consulting                45
# 7924  10,001+ employees · IT Services and IT Consulting                15
#
#      posted_day_ago    Hiring_person    linkedin_followers  \
# 3           7 hours    Vartika Singh       2,094 followers
# 7           7 hours  Rashmi Aggarwal       1,045 followers
# 8        25 minutes     Duncan Lawie      30,319 followers
# 10         10 hours     Yamini Gupta       4,780 followers
# 11          5 hours       Neha Yadav     198,797 followers
# ...             ...              ...                   ...
# 7917         2 days  Benjamin Rajesh      38,790 followers
# 7918         4 days    Abhi Nerurkar       2,354 followers
# 7919         3 days          SUNIL N      13,280 followers
# 7920          1 day  Madhuri Mahajan  11,923,632 followers
# 7924         6 days     ANNIE ANTONY  11,923,634 followers
#
#                                             job_details
# 3     About the job Designation: Data AnalystLocatio...
# 7     About the job The ideal candidate will be resp...
# 8     About the job Are you an experienced Microsoft...
# 10    About the job Create an engaging and knowledge...
# 11    About the job About the organizationFounded in...
# ...                                                 ...
# 7917  About the job · The person should have an expe...
# 7918  About the job EPMware is seeking a Senior Java...
# 7919  About the job Position: - AWS Cloud Specialist...
# 7920  About the job Dear Candidate, Greetings from T...
# 7924  About the job Role- Vue js DeveloperExperience...
#
# [3459 rows x 13 columns]

# %%
# 11 Cleaning individual columns

# %%
data.no_of_employ
# Out:
# 3                                          1-10 employees
# 7                                        51-200 employees
# 8                                       201-500 employees
# 10                                        11-50 employees
# 11      501-1,000 employees · Renewable Energy Semicon...
#                               ...
# 7917      201-500 employees · Semiconductor Manufacturing
# 7918                                      11-50 employees
# 7919         201-500 employees · Human Resources Services
# 7920    10,001+ employees · IT Services and IT Consulting
# 7924    10,001+ employees · IT Services and IT Consulting
# Name: no_of_employ, Length: 3459, dtype: str

# %%
# Splitting the no. of employees and industry into 2 columns
data['no_of_employ'].str.split('·', n=1, expand = True).rename(columns = {0:'no_of_employees', 1:'industry'})
# Out:
#            no_of_employees                                       industry
# 3           1-10 employees                                            NaN
# 7         51-200 employees                                            NaN
# 8        201-500 employees                                            NaN
# 10         11-50 employees                                            NaN
# 11    501-1,000 employees    Renewable Energy Semiconductor Manufacturing
# ...                    ...                                            ...
# 7917    201-500 employees                     Semiconductor Manufacturing
# 7918       11-50 employees                                            NaN
# 7919    201-500 employees                        Human Resources Services
# 7920    10,001+ employees                   IT Services and IT Consulting
# 7924    10,001+ employees                   IT Services and IT Consulting
#
# [3459 rows x 2 columns]

# %%
data [['no_of_employees', 'industry']] = data['no_of_employ'].str.split('·', n=1, expand = True)

# %%
data.columns
# Out:
# Index(['job_ID', 'job', 'location', 'company_id', 'company_name', 'work_type',
#        'full_time_remote', 'no_of_employ', 'no_of_application',
#        'posted_day_ago', 'Hiring_person', 'linkedin_followers', 'job_details',
#        'no_of_employees', 'industry'],
#       dtype='str')

# %%
data.drop(columns= ['no_of_employ'])
# Out:
#           job_ID                             job                     location  \
# 3     3472816027                    Data Analyst     Gurugram, Haryana, India
# 7     3472808738               Shopify Developer                 Delhi, India
# 8     3475061559              Database Developer     Gurugram, Haryana, India
# 10    3471883751               Shopify Developer  Noida, Uttar Pradesh, India
# 11    3467390929                   Data Engineer     Gurugram, Haryana, India
# ...          ...                             ...                          ...
# 7917  3466122931   LINUX DEVICE DRIVER DEVELOPER  Bengaluru, Karnataka, India
# 7918  3469629784  Senior Java Software Developer     Pune, Maharashtra, India
# 7919  3471741258            AWS Cloud Specialist  Hyderabad, Telangana, India
# 7920  3466165399                   LTE Developer  Hyderabad, Telangana, India
# 7924  3461005032                          Vue JS  Hyderabad, Telangana, India
#
#       company_id                company_name work_type  \
# 3              3               PVAR SERVICES   On-site
# 7              6         Digital Impressions   On-site
# 8              7             Kline & Company    Hybrid
# 10             9       Unitalks Technologies    Remote
# 11            10                 ReNew Power   On-site
# ...          ...                         ...       ...
# 7917        2492  SmartSoC Solutions Pvt Ltd   On-site
# 7918        2493                     EPMware    Remote
# 7919        2494                       Altvu    Hybrid
# 7920          22   Tata Consultancy Services    Hybrid
# 7924          22   Tata Consultancy Services   On-site
#
#                   full_time_remote no_of_application posted_day_ago  \
# 3                        Full-time               200        7 hours
# 7                        Full-time                 2        7 hours
# 8                        Full-time                 7     25 minutes
# 10                       Full-time                22       10 hours
# 11    Full-time · Mid-Senior level               111        5 hours
# ...                            ...               ...            ...
# 7917   Contract · Mid-Senior level                10         2 days
# 7918                     Full-time                99         4 days
# 7919  Full-time · Mid-Senior level                52         3 days
# 7920                     Full-time                45          1 day
# 7924  Full-time · Mid-Senior level                15         6 days
#
#         Hiring_person    linkedin_followers  \
# 3       Vartika Singh       2,094 followers
# 7     Rashmi Aggarwal       1,045 followers
# 8        Duncan Lawie      30,319 followers
# 10       Yamini Gupta       4,780 followers
# 11         Neha Yadav     198,797 followers
# ...               ...                   ...
# 7917  Benjamin Rajesh      38,790 followers
# 7918    Abhi Nerurkar       2,354 followers
# 7919          SUNIL N      13,280 followers
# 7920  Madhuri Mahajan  11,923,632 followers
# 7924     ANNIE ANTONY  11,923,634 followers
#
#                                             job_details       no_of_employees  \
# 3     About the job Designation: Data AnalystLocatio...        1-10 employees
# 7     About the job The ideal candidate will be resp...      51-200 employees
# 8     About the job Are you an experienced Microsoft...     201-500 employees
# 10    About the job Create an engaging and knowledge...       11-50 employees
# 11    About the job About the organizationFounded in...  501-1,000 employees
# ...                                                 ...                   ...
# 7917  About the job · The person should have an expe...    201-500 employees
# 7918  About the job EPMware is seeking a Senior Java...       11-50 employees
# 7919  About the job Position: - AWS Cloud Specialist...    201-500 employees
# 7920  About the job Dear Candidate, Greetings from T...    10,001+ employees
# 7924  About the job Role- Vue js DeveloperExperience...    10,001+ employees
#
#                                            industry
# 3                                               NaN
# 7                                               NaN
# 8                                               NaN
# 10                                              NaN
# 11     Renewable Energy Semiconductor Manufacturing
# ...                                             ...
# 7917                    Semiconductor Manufacturing
# 7918                                            NaN
# 7919                       Human Resources Services
# 7920                  IT Services and IT Consulting
# 7924                  IT Services and IT Consulting
#
# [3459 rows x 14 columns]
